# %%
pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 4.8 MB/s
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (965 kB)
#      |████████████████████████████████| 965 kB 60.2 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.10)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.64.1)
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.8 pyvi-0.1.1 sklearn-crfsuite-0.3.6

# %%
from pyvi import ViTokenizer, ViPosTagger # thư viện NLP tiếng Việt
from tqdm import tqdm
import numpy as np
import gensim # thư viện NLP
import os
import pickle

# %%
from keras import Input
from keras.layers import Dense, BatchNormalization
from sklearn.model_selection import train_test_split
from keras.models import Sequential
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from keras.models import Model
from keras.layers import Flatten, Dropout

from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam

# %%
X_data = pickle.load(open('/content/drive/MyDrive/Python/CS431/data/10Topics/X_data.pkl', 'rb'))
y_data = pickle.load(open('/content/drive/MyDrive/Python/CS431/data/10Topics/y_data.pkl', 'rb'))

X_test = pickle.load(open('/content/drive/MyDrive/Python/CS431/data/10Topics/X_test.pkl', 'rb'))
y_test = pickle.load(open('/content/drive/MyDrive/Python/CS431/data/10Topics/y_test.pkl', 'rb'))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tfidf_vect = TfidfVectorizer(analyzer='word', max_features=30000)
tfidf_vect.fit(X_data) # learn vocabulary and idf from training set
X_data_tfidf =  tfidf_vect.transform(X_data)
# assume that we don't have test set before
X_test_tfidf =  tfidf_vect.transform(X_test)

# %%
tfidf_vect.get_feature_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['aa',
#  'aaa',
#  'aac',
#  'aachen',
#  'aaron',
#  'aas',
#  'ab',
#  'aba',
#  'abashidze',
#  'abba',
#  'abbas',
#  'abbey',
#  'abbiati',
#  'abbondanzieri',
#  'abbott',
#  'abc',
#  'abd',
#  'abdel',
#  'abdelrahim',
#  'abdoulaye',
#  'abdul',
#  'abdulaziz',
#  'abdullah',
#  'abe',
#  'abel',
#  'aberdeen',
#  'abeyie',
#  'abf',
#  'abidjan',
#  'abkhazia',
#  'able',
#  'abn',
#  'about',
#  'abqaiq',
#  'abraham',
#  'abramoff',
#  'abramovich',
#  'abs',
#  'abtc',
#  'abu',
#  'ac',
#  'academy',
#  'acasiete',
#  'acb',
#  'acbs',
#  'accc',
#  'accept',
#  'access',
#  'account',
#  'accumbens',
#  'ace',
#  'aceh',
#  'acer',
#  'acetaminophen',
#  'achilefu',
#  'achilles',
#  'acid',
#  'acid_amin',
#  'acid_béo',
#  'acl',
#  'acm',
#  'acoo',
#  'acpe',
#  'acrobat',
#  'acronis',
#  'acropolis',
#  'acrylic',
#  'act',
#  'action',
#  'active',
#  'activex',
#  'acuff',
#  'acyclovir',
#  'ad',
#  'adam',
#  'adams',
#  'adan',
#  'adani',
#  'adapter',
#  'adb',
#  'add',
#  'address',
#  'addvote',
#  'adebayor',
#  'adelaide',
#  'adelman',
#  'aden',
#  'adeno',
#  'adeportivo',
#  'adidas',
#  'adler',
#  'admin',
#  'adn',
#  'adnan',
#  'adobe',
#  'adodb',
#  'adrenalin',
#  'adrenaline',
#  'adrian',
#  'adriano',
#  'adsl',
#  'adu',
#  'adulyadej',
#  'aduôm',
#  'advanced',
#  'adventure',
#  'adventures',
#  'advocaat',
#  'adware',
#  'adzharia',
#  'ae',
#  'aegypti',
#  'aek',
#  'aerobic',
#  'aerospace',
#  'af',
#  'afa',
#  'afc',
#  'afd',
#  'aff',
#  'affleck',
#  'afghanistan',
#  'afp',
#  'afta',
#  'after',
#  'ag',
#  'again',
#  'agamemnon',
#  'agassi',
#  'age',
#  'agf',
#  'agger',
#  'agifish',
#  'agnelli',
#  'agobot',
#  'agostino',
#  'agra',
#  'agresto',
#  'agribank',
#  'agricole',
#  'ags',
#  'agtek',
#  'agu',
#  'aguilar',
#  'aguilera',
#  'agus',
#  'agustin',
#  'ah',
#  'aha',
#  'ahern',
#  'ahmad',
#  'ahmadinejad',
#  'ahmed',
#  'ahn',
#  'ahv',
#  'ai',
#  'ai_ai',
#  'ai_bảo',
#  'ai_lại',
#  'ai_ngờ',
#  'ai_nấy',
#  'ai_đời',
#  'aia',
#  'aiboy',
#  'aid',
#  'aide',
#  'aids',
#  'aiko',
#  'ailen',
#  'ailton',
#  'aim',
#  'aimar',
#  'aime',
#  'ain',
#  'aio',
#  'air',
#  'airbus',
#  'aires',
#  'airlines',
#  'airways',
#  'ait',
#  'aitor',
#  'aiyegbeni',
#  'aj',
#  'ajax',
#  'ajc',
#  'ajinomoto',
#  'ak',
#  'akayev',
#  'akbar',
#  'akhtar',
#  'akinfeev',
#  'akira',
#  'akishino',
#  'al',
#  'ala',
#  'alabama',
#  'alain',
#  'alam',
#  'alamsyah',
#  'alan',
#  'alarm',
#  'alaska',
#  'alaves',
#  'alawi',
#  'alba',
#  'albacete',
#  'albania',
#  'albelda',
#  'albena',
#  'albert',
#  'alberta',
#  'albertini',
#  'alberto',
#  'albion',
#  'albright',
#  'album',
#  'albumin',
#  'alcatel',
#  'alcomto',
#  'aldo',
#  'aldonin',
#  'ale',
#  'alec',
#  'alegre',
#  'alejandro',
#  'aleksander',
#  'aleksandr',
#  'aleksandrs',
#  'alenichev',
#  'alert',
#  'alessandro',
#  'alessio',
#  'alex',
#  'alexander',
#  'alexandra',
#  'alexandre',
#  'alexandria',
#  'alexei',
#  'alexey',
#  'alexis',
#  'alezboo',
#  'alfa',
#  'alfonso',
#  'alfred',
#  'alfredo',
#  'algeria',
#  'ali',
#  'aliadiere',
#  'alice',
#  'alicia',
#  'alienware',
#  'alive',
#  'aliénor',
#  'alkmaar',
#  'all',
#  'alla',
#  'allah',
#  'allan',
#  'allardyce',
#  'allawi',
#  'allback',
#  'allen',
#  'allende',
#  'alley',
#  'alliance',
#  'allianz',
#  'almeida',
#  'almeyda',
#  'almunia',
#  'alofun',
#  'alonso',
#  'alpe',
#  'alpha',
#  'alphanam',
#  'alphonse',
#  'alpi',
#  'alps',
#  'alt',
#  'altavista',
#  'alternative',
#  'altintop',
#  'altis',
#  'alvarez',
#  'alvaro',
#  'alves',
#  'alvin',
#  'alwaleed',
#  'alzheimer',
#  'alô',
#  'am',
#  'am_hiểu',
#  'am_tường',
#  'ama',
#  'amador',
#  'aman',
#  'amanda',
#  'amantadine',
#  'amaobi',
#  'amara',
#  'amarilla',
#  'amaseco',
#  'amath',
#  'amazon',
#  'ambrose',
#  'ambrosini',
#  'ambrosio',
#  'amcham',
#  'amd',
#  'amedeo',
#  'amelia',
#  'amelie',
#  'ameobi',
#  'america',
#  'american',
#  'amie',
#  'amin',
#  'amino',
#  'amir',
#  'amiro',
#  'amiăng',
#  'amiđan',
#  'amjad',
#  'amma',
#  'amman',
#  'ammar',
#  'amoniac',
#  'amore',
#  'amoro',
#  'amoroso',
#  'amoruso',
#  'amour',
#  'amoxicillin',
#  'amp',
#  'ampad',
#  'ampli',
#  'amposted',
#  'amr',
#  'amri',
#  'amsterdam',
#  'amstrong',
#  'amsubject',
#  'amy',
#  'amíp',
#  'an',
#  'an_bài',
#  'an_cư',
#  'an_giang',
#  'an_hưởng',
#  'an_khang',
#  'an_khê',
#  'an_lành',
#  'an_lạc',
#  'an_nghỉ',
#  'an_nhàn',
#  'an_ninh',
#  'an_phận',
#  'an_sinh',
#  'an_thần',
#  'an_toàn',
#  'an_táng',
#  'an_tâm',
#  'an_ủi',
#  'ana',
#  'analog',
#  'analytics',
#  'anara',
#  'anastasia',
#  'anatoly',
#  'anbar',
#  'ancelotti',
#  'ancic',
#  'ancona',
#  'and',
#  'andaman',
#  'anderlecht',
#  'anders',
#  'andersen',
#  'anderson',
#  'andersson',
#  'anderton',
#  'andes',
#  'andorra',
#  'andrade',
#  'andre',
#  'andrea',
#  'andreas',
#  'andreev',
#  'andrei',
#  'andreina',
#  'andrejs',
#  'andres',
#  'andrew',
#  'andrews',
#  'andrey',
#  'andriy',
#  'androgen',
#  'andré',
#  'andy',
#  'anelka',
#  'anfield',
#  'ang',
#  'angel',
#  'angela',
#  'angeles',
#  'angelina',
#  'angelo',
#  'angelos',
#  'angels',
#  'angkor',
#  'anglia',
#  'angola',
#  'angresto',
#  'angulo',
#  'anh',
#  'anh_chàng',
#  'anh_chị',
#  'anh_chị_em',
#  'anh_dũng',
#  'anh_em',
#  'anh_em_trai',
#  'anh_hùng',
#  'anh_hùng_ca',
#  'anh_linh',
#  'anh_minh',
#  'anh_trai',
#  'anh_túc',
#  'anh_vũ',
#  'anh_ách',
#  'anh_ánh',
#  'anh_đào',
#  'anhto',
#  'anigo',
#  'anisensel',
#  'aniston',
#  'ankara',
#  'ann',
#  'anna',
#  'annan',
#  'anne',
#  'anolyte',
#  'another',
#  'anousone',
#  'ansar',
#  'antar',
#  'anten',
#  'anthony',
#  'anti',
#  'antigua',
#  'antioquia',
#  'antivirus',
#  'anto',
#  'antoine',
#  'antoinette',
#  'anton',
#  'antonio',
#  'antonioli',
#  'antonis',
#  'antony',
#  'antt',
#  'anwar',
#  'anz',
#  'anđt',
#  'ao',
#  'ao_ước',
#  'aol',
#  'ap',
#  'apache',
#  'apartheid',
#  'apd',
#  'apec',
#  'aperture',
#  'aphrodite',
#  'api',
#  'apollo',
#  'appf',
#  'appiah',
#  'apple',
#  'applet',
#  'application',
#  'apply',
#  'april',
#  'aps',
#  'apsara',
#  'aptech',
#  'apu',
#  'apwg',
#  'aqa',
#  'aqsa',
#  'aqua',
#  'aquarium',
#  'aquilani',
#  'aquino',
#  'ara',
#  'arab',
#  'araban',
#  'arabia',
#  'arabiya',
#  'arad',
#  'arafat',
#  'aragones',
#  'arakawa',
#  'aral',
#  'aranda',
#  'arango',
#  'aranzubia',
#  'araujo',
#  'arazi',
#  'archaeopteryx',
#  'architecture',
#  'archiver',
#  'archives',
#  'arctangza',
#  'are',
#  'arellano',
#  'arem',
#  'arena',
#  'argentina',
#  'argilli',
#  'arginine',
#  'argon',
#  'ari',
#  'aria',
#  'ariane',
#  'aric',
#  'arie',
#  'ariel',
#  'aris',
#  'aristide',
#  'ariza',
#  'arizona',
#  'arjen',
#  'arjhan',
#  'arkansas',
#  'arles',
#  'arlington',
#  'armand',
#  'armando',
#  'armani',
#  'armavia',
#  'armenia',
#  'arminia',
#  'armitage',
#  'armstrong',
#  'arn',
#  'arnaud',
#  'arne',
#  'arnold',
#  'arosa',
#  'array',
#  'arrese',
#  'arrichion',
#  'arrigo',
#  'arroyo',
#  'arruabarrena',
#  'arsen',
#  'arsenal',
#  'arsenal_chấp',
#  'arsene',
#  'arshavin',
#  'art',
#  'artemio',
#  'artemisinin',
#  'arteta',
#  'arthur',
#  'articleid',
#  'artmedia',
#  'arts',
#  'arturo',
#  'arv',
#  'arập',
#  'as',
#  'asa',
#  'asada',
#  'asahara',
#  'asahi',
#  'asamoah',
#  'ascender',
#  'ascii',
#  'ascoli',
#  'asda',
#  'asean',
#  'asefi',
#  'asem',
#  'asep',
#  'asf',
#  'asha',
#  'ashampoo',
#  'ashanti',
#  'ashcroft',
#  'ashdown',
#  'ashfaq',
#  'ashima',
#  'ashlee',
#  'ashley',
#  'ashraf',
#  'ashton',
#  'asia',
#  'asiad',
#  'asian',
#  'asianux',
#  'asic',
#  'asimo',
#  'asin',
#  'ask',
#  'aslan',
#  'aslem',
#  'asn',
#  'aso',
#  'asp',
#  'aspect',
#  'asperger',
#  'aspergillus',
#  'aspilia',
#  'aspire',
#  'aspirin',
#  'aspirine',
#  'aspx',
#  'assad',
#  'assam',
#  'assis',
#  'associates',
#  'association',
#  'astafjevs',
#  'astaman',
#  'aston',
#  'asuka',
#  'asus',
#  'at',
#  'ata',
#  'atak',
#  'atal',
#  'atalanta',
#  'atay',
#  'atb',
#  'atc',
#  'atf',
#  'atgt',
#  'athen',
#  'athens',
#  'athletic',
#  'athlon',
#  'ati',
#  'atisô',
#  'atl',
#  'atlanta',
#  'atlantic',
#  'atlantis',
#  'atlas',
#  'atletico',
#  'atm',
#  'atminfor',
#  'atomic',
#  'atp',
#  'atr',
#  'att',
#  'attack',
#  'atthipol',
#  'attila',
#  'attogiây',
#  'atvstp',
#  'atâu',
#  'au',
#  'auc',
#  'auckland',
#  'aud',
#  'audi',
#  'audio',
#  'audrey',
#  'augenthaler',
#  'august',
#  'augusto',
#  'augustus',
#  'aulas',
#  'aum',
#  'aung',
#  'aura',
#  'aurelio',
#  'austin',
#  'australia',
#  'australian',
#  'auto',
#  'autocad',
#  'autodesk',
#  'automatic',
#  'automobile',
#  'automotive',
#  'autopetro',
#  'auxerre',
#  'av',
#  'ava',
#  'avaya',
#  'avc',
#  'aventis',
#  'avenue',
#  'avery',
#  'avg',
#  'avi',
#  'aviator',
#  'aviv',
#  'avon',
#  'avramovic',
#  'avril',
#  'award',
#  'awards',
#  'aware',
#  'away',
#  'ax',
#  'axa',
#  'axel',
#  'axen',
#  'axit',
#  'axít',
#  'ay',
#  'ayad',
#  'ayala',
#  'aye',
#  'ayman',
#  'ayovi',
#  'ayre',
#  'ayrton',
#  'ayub',
#  'az',
#  'azahari',
#  'azerbaijan',
#  'azevedo',
#  'azithromycin',
#  'aziz',
#  'aztec',
#  'aztecs',
#  'azul',
#  'azzam',
#  'aê',
#  'ba',
#  'ba_ba',
#  'ba_bị',
#  'ba_bốn',
#  'ba_chỉ',
#  'ba_cùng',
#  'ba_gác',
#  'ba_hoa',
#  'ba_kích',
#  'ba_la',
#  'ba_lá',
#  'ba_lê',
#  'ba_lô',
#  'ba_má',
#  'ba_phải',
#  'ba_rọi',
#  'baath',
#  'babayaro',
#  'babel',
#  'babic',
#  'baby',
#  'babylon',
#  'bac',
#  'bach',
#  'bachelet',
#  'bachri',
#  'back',
#  'backdoor',
#  'backstedt',
#  'backstreet',
#  'backup',
#  'bacolod',
#  'bad',
#  'badawi',
#  'baden',
#  'bae',
#  'baez',
#  'baggio',
#  'baghdad',
#  'baghdatis',
#  'bagle',
#  'bahamas',
#  'bahnar',
#  'bahrain',
#  'baht',
#  'bai',
#  'baia',
#  'baiano',
#  'baidu',
#  'baihakki',
#  'baikal',
#  'baikonur',
#  'bakar',
#  'baker',
#  'bakery',
#  'bakiev',
#  'baku',
#  'baldini',
#  'baldwin',
#  'balears',
#  'bali',
#  'balkan',
#  'balkans',
#  'ball',
#  'ballack',
#  'ballad',
#  'balladur',
#  'ballast',
#  'ballesta',
#  'ballet',
#  'balli',
#  'ballmer',
#  'baltic',
#  'baltimore',
#  'balzaretti',
#  'balô',
#  'bam',
#  'bambang',
#  'ban',
#  'ban_bố',
#  'ban_công',
#  'ban_công_tác',
#  'ban_hành',
#  'ban_hành_pháp_lệnh',
#  'ban_hành_quyết_định',
#  'ban_hành_văn_bản',
#  'ban_mai',
#  'ban_ngành',
#  'ban_ngày',
#  'ban_phát',
#  'ban_tặng',
#  'ban_đêm',
#  'ban_đầu',
#  'ban_ơn',
#  'bana',
#  'band',
#  'banda',
#  'bandar',
#  'bandung',
#  'bang',
#  'bang_giao',
#  'bangalore',
#  'bangkok',
#  'bangladesh',
#  'banh',
#  'banh_nửa',
#  'bank',
#  'banking',
#  'banknet',
#  'banks',
#  'banluesak',
#  'banner',
#  'bao',
#  'bao_biện',
#  'bao_bì',
#  'bao_bọc',
#  'bao_che',
#  'bao_cấp',
#  'bao_dung',
#  'bao_giờ',
#  'bao_gói',
#  'bao_gồm',
#  'bao_hàm',
#  'bao_la',
#  'bao_lâu',
#  'bao_lâu_nay',
#  'bao_nhiêu',
#  'bao_phủ',
#  'bao_quát',
#  'bao_sân',
#  'bao_tay',
#  'bao_tiêu',
#  'bao_trùm',
#  'bao_tải',
#  'bao_tử',
#  'bao_vây',
#  'bao_xa',
#  'baptista',
#  'baquba',
#  'bar',
#  'baraja',
#  'barbara',
#  'barbie',
#  'barbiero',
#  'barbosa',
#  'barca',
#  'barcelona',
#  'barclays',
#  'bardot',
#  'barghouti',
#  'bari',
#  'baric',
#  'barie',
#  'barleygrass',
#  'barlow',
#  'barnes',
#  'barney',
#  'barnier',
#  'barone',
#  'baros',
#  'barr',
#  'barracuda',
#  'barreto',
#  'barrett',
#  'barrichello',
#  'barrie',
#  'barroso',
#  'barrot',
#  'barry',
#  'barrymore',
#  'bart',
#  'barthez',
#  'bartlett',
#  'barton',
#  'barwick',
#  'bas',
#  'basa',
#  'basayev',
#  'base',
#  'based',
#  'basedow',
#  'basel',
#  'bashir',
#  'basic',
#  'basil',
#  'basinas',
#  'basque',
#  'basra',
#  'bass',
#  'basso',
#  'basten',
#  'bastian',
#  'bat',
#  'bates',
#  'bath',
#  'baumann',
#  'baumgardner',
#  'baumgartner',
#  'bautista',
#  'bavaria',
#  'bavet',
#  'bay',
#  'bay_bướm',
#  'bay_bổng',
#  'bay_hơi',
#  'bay_lượn',
#  'bay_nhảy',
#  'bayati',
#  'bayer',
#  'bayern',
#  'bazan',
#  'bazzani',
#  'bađm',
#  'bb',
#  'bbc',
#  'bbt',
#  'bbàn',
#  'bc',
#  'bca',
#  'bcb',
#  'bcc',
#  'bch',
#  'bcht',
#  'bchtư',
#  'bci',
#  'bct',
#  'bcvt',
#  'bd',
#  'bdd',
#  'bdelloid',
#  'bdr',
#  'bdynamo',
#  'be',
#  'be_bé',
#  'be_bét',
#  'bea',
#  'beach',
#  'beagle',
#  'bean',
#  'beasley',
#  'beatles',
#  'beattie',
#  'beaujolais',
#  'beautiful',
#  'beauty',
#  'bec',
#  'becamex',
#  'becgiê',
#  'beck',
#  'beckenbauer',
#  'becker',
#  'beckham',
#  'becks',
#  'bee',
#  'been',
#  'beenhakker',
#  'beer',
#  'beethoven',
#  'bega',
#  'begin',
#  'behari',
#  'behr',
#  'beijing',
#  'beirut',
#  'bejan',
#  'belanov',
#  'belarus',
#  ...]

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=300, random_state=42)
svd.fit(X_data_tfidf)
# Out:
# TruncatedSVD(n_components=300, random_state=42)

# %%
X_data_tfidf_svd = svd.transform(X_data_tfidf)
X_test_tfidf_svd = svd.transform(X_test_tfidf)

# %%
from sklearn import preprocessing, metrics
encoder = preprocessing.LabelEncoder()
y_data_n = encoder.fit_transform(y_data)
y_test_n = encoder.fit_transform(y_test)

encoder.classes_
# Out:
# array(['Chinh tri Xa hoi', 'Doi song', 'Khoa hoc', 'Kinh doanh',
#        'Phap luat', 'Suc khoe', 'The gioi', 'The thao', 'Van hoa',
#        'Vi tinh'], dtype='<U16')

# %%
def plot_model_history(model_history, acc='accuracy'):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    axs[0].plot(range(1, len(model_history.history[acc]) + 1), model_history.history[acc])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1, len(model_history.history[acc]) + 1), len(model_history.history[acc]) / 10)
    axs[0].legend(['train'], loc='best')
    axs[1].plot(range(1, len(model_history.history['loss']) + 1), model_history.history['loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1, len(model_history.history['loss']) + 1), len(model_history.history['loss']) / 10)
    axs[1].legend(['train'], loc='best')
    plt.show()

# %%
epochs=50
learning_rate=0.001

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=4)

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.1,
    decay_steps=10000,
    decay_rate=0.9)

# %%
adam = Adam(learning_rate=lr_schedule)
sgd = SGD(learning_rate=lr_schedule)

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix, plot_roc_curve, classification_report, auc

# %%
def print_cmx(y_true, y_pred):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cmx, annot=True, fmt='g')
    print(cmx_data)
    plt.show()

# %%
def create_dnn_model():
    input_layer = Input(shape=(300,))
    layer = Dense(1024, activation='relu')(input_layer)
    layer = Dense(512, activation='relu')(layer)
    layer = Dense(128, activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = Dropout(0.4)(layer)
    output_layer = Dense(10, activation='softmax')(layer)
    classifier = Model(input_layer, output_layer)
    classifier.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return classifier

# %%
def train_model(classifier, X_data, y_data, X_test, y_test, is_neuralnet=False, epochs=epochs):       
    X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.1, random_state=42)
    
    model_history = classifier.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, batch_size=32,callbacks=[earlystopping])
    
    val_predictions = classifier.predict(X_val)
    test_predictions = classifier.predict(X_test)
    val_predictions = val_predictions.argmax(axis=-1)
    test_predictions = test_predictions.argmax(axis=-1)
        
    print("Validation accuracy: ", metrics.accuracy_score(val_predictions, y_val))
    print("Test accuracy: ", metrics.accuracy_score(test_predictions, y_test))
    plot_model_history(model_history)
    
    target_names = ["Class {}".format(i) for i in range(10)]
    print(classification_report(test_predictions, y_test, target_names=target_names))
    print_cmx(test_predictions, y_test)

# %%
classifier=create_dnn_model()

# %%
train_model(classifier=classifier, X_data=X_data_tfidf_svd, y_data=y_data_n, X_test=X_test_tfidf_svd, y_test=y_test_n)
# Out:
# Epoch 1/50
# 950/950 [==============================] - 7s 4ms/step - loss: 0.8423 - accuracy: 0.7613 - val_loss: 0.7734 - val_accuracy: 0.8617
# Epoch 2/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.6815 - accuracy: 0.8328 - val_loss: 0.5866 - val_accuracy: 0.8534
# Epoch 3/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.6684 - accuracy: 0.8490 - val_loss: 0.5752 - val_accuracy: 0.8661
# Epoch 4/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.6677 - accuracy: 0.8625 - val_loss: 1.1997 - val_accuracy: 0.8741
# Epoch 5/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4865 - accuracy: 0.8873 - val_loss: 0.9628 - val_accuracy: 0.8711
# Epoch 6/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.5980 - accuracy: 0.8798 - val_loss: 1.3078 - val_accuracy: 0.8957
# Epoch 7/50
# 950/950 [==============================] - 4s 5ms/step - loss: 0.4700 - accuracy: 0.9041 - val_loss: 2.8674 - val_accuracy: 0.8836
# Epoch 8/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.5822 - accuracy: 0.9031 - val_loss: 2.3058 - val_accuracy: 0.8818
# Epoch 9/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4550 - accuracy: 0.9190 - val_loss: 0.9179 - val_accuracy: 0.8937
# Epoch 10/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4052 - accuracy: 0.9307 - val_loss: 1.3598 - val_accuracy: 0.8717
# Epoch 11/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4590 - accuracy: 0.9320 - val_loss: 2.9482 - val_accuracy: 0.8916
# Epoch 12/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4821 - accuracy: 0.9377 - val_loss: 1.1444 - val_accuracy: 0.8886
# Epoch 13/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.3364 - accuracy: 0.9523 - val_loss: 5.7364 - val_accuracy: 0.8940
# Epoch 14/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4875 - accuracy: 0.9449 - val_loss: 1.3440 - val_accuracy: 0.8948
# Epoch 15/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.3791 - accuracy: 0.9576 - val_loss: 2.4698 - val_accuracy: 0.8700
# Epoch 16/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.3591 - accuracy: 0.9608 - val_loss: 1.8452 - val_accuracy: 0.9008
# Epoch 17/50
# 950/950 [==============================] - 4s 4ms/step - loss: 0.4208 - accuracy: 0.9618 - val_loss: 9.9510 - val_accuracy: 0.8907
# 106/106 [==============================] - 0s 2ms/step
# 1575/1575 [==============================] - 3s 2ms/step
# Validation accuracy:  0.8906990521327014
# Test accuracy:  0.8937923093720842
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   del sys.path[0]
#               precision    recall  f1-score   support
#
#      Class 0       0.86      0.85      0.85      7657
#      Class 1       0.75      0.54      0.63      2827
#      Class 2       0.67      0.85      0.75      1650
#      Class 3       0.89      0.89      0.89      5297
#      Class 4       0.87      0.92      0.90      3591
#      Class 5       0.94      0.91      0.92      5597
#      Class 6       0.85      0.98      0.91      5830
#      Class 7       0.98      0.98      0.98      6653
#      Class 8       0.93      0.92      0.93      6330
#      Class 9       0.97      0.89      0.93      4941
#
#     accuracy                           0.89     50373
#    macro avg       0.87      0.87      0.87     50373
# weighted avg       0.90      0.89      0.89     50373
#
# [[6495  109   86  275  310   74  136   22  131   19]
#  [ 296 1537  297   50   36  128  215   24  214   30]
#  [  39   20 1403   20    1   65   67    6   10   19]
#  [ 194   25   27 4714   62   14  208    4    9   40]
#  [ 152   18    1   32 3309    9   32   23    6    9]
#  [ 135   49  140   19   18 5093  119    9   10    5]
#  [  22   21   13   15    1    5 5713   11   19   10]
#  [  21   14    5    4   22   12   28 6529   11    7]
#  [  91  215   39   11   15    4   92   26 5823   14]
#  [ 122   28   85  136   14   13  106   13   17 4407]]
